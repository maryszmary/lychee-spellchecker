# %%
import tqdm
import re
import numpy as np
from collections import Counter

# %%
class LanguageModel():
    def __init__(self, order=2):
        self.order=order

    def fit(self, corpus):
        self.counts = get_counts(corpus, self.order)
        
    def prob(self, string, log=False):
        return interpolate(self.counts, string, self.order, log=log)
        
    def product(nums):
        "Multiply the numbers together.  (Like `sum`, but with multiplication.)"
        result = 1
        for x in nums: result *= x
        return result

    def get_ngrams(tokens, n):
        return [' '.join(tokens[i:i+n]) for i, token in enumerate(tokens)]
    
    def get_counts(corpus, order):  
        counts = {'n' + str(i) : Counter(get_ngrams(corpus, n=i)) for i in range(1, order+1)}
        counts['n0'] = {'':len(corpus)}
        return counts
    
    def get_prob(counts, word, context=''):
        '''With Laplace shoothing as yet.
        Not for public use.'''
        order = len(context.split())+1
        separator = ' ' if order > 1 else ''
        return (counts['n'+str(order)][separator.join([context, word])] + 1) / \
               (counts['n'+str(order-1)][context] + len(counts['n'+str(order)]))
        
    def get_logprob(counts, word, context=''):
        return np.log(get_prob(counts, word, context))
    
    def get_following(counts, context):
        '''Slow as hell. 
        To optimize might use embedded dictionaries.'''
        order = len(context.split())+1
        return sorted(
            [(k.split()[-1], v, get_prob(counts, k.split()[-1], context)) \
            for k, v in counts['n'+str(order)].items()                    \
            if re.match(context+' '+'\w+', k)],                           \
            key=lambda x:x[1], reverse=True)   
    
    def get_string_probs(counts, string, order, log=True):
        prob_fun = get_logprob if log else get_prob
        tokens = string.split()
        probs = []
        for i in range(len(tokens)):
            context = ' '.join(tokens[i-order+1:i]) if i>=order else ' '.join(tokens[:i])
            prob = prob_fun(counts, word = tokens[i], context = context)
            probs.append(prob)
        return probs
    
    def interpolate(counts, string, order, log=True, lambdas='default'):
        lmbd = [0.3, 0.7] if lambdas == 'default' else lambdas
        aggregate = sum if log else product
        probs = [get_string_probs(counts, string, order=i, log=log) for i in range(1, order+1)]
        probs_interpolated = []
        for tup in zip(*probs):
            prob_token = 0
            for i in range(len(tup)):
                prob_token += tup[i] * lmbd[i]
            probs_interpolated.append(prob_token)
        return aggregate(probs_interpolated)

# %%
def cleanse(s, rgxp = '[\W\da-z]'):
    return re.sub(' +', ' ', re.sub(rgxp, ' ', s.lower()))

# %%
with open('lt1.txt', encoding='utf-8') as f:
    tokens = cleanse(f.read().lower()).split()

# %%
# %%time
model = LanguageModel(order=2)
model.fit(tokens)
# Out:
# Wall time: 656 ms

# %%
# %%time
model.prob('наташа')
# Out:
# Wall time: 0 ns
# 0.001646777278875629

# %%
# %%time
model.prob('наташа и пьер не хотели ехать')
# Out:
# Wall time: 0 ns
# 5.515250993684362e-19

# %%
model.counts
# Out:
# {'n0': {'': 451046},
#  'n1': Counter({'л': 15,
#           'н': 15,
#           'толстой': 11,
#           'война': 64,
#           'и': 21710,
#           'мир': 51,
#           'том': 780,
#           'первый': 178,
#           'часть': 84,
#           'первая': 32,
#           'е': 46,
#           'к': 3629,
#           'поместья': 1,
#           'й': 1066,
#           'мой': 317,
#           'верный': 6,
#           'раб': 7,
#           'см': 16,
#           'сноски': 32,
#           'в': 11173,
#           'конце': 72,
#           'части': 51,
#           'ну': 568,
#           'здравствуйте': 13,
#           'садитесь': 7,
#           'рассказывайте': 2,
#           'так': 2032,
#           'говорила': 267,
#           'июле': 2,
#           'года': 112,
#           'известная': 11,
#           'анна': 208,
#           'павловна': 100,
#           'шерер': 9,
#           'фрейлина': 3,
#           'приближенная': 1,
#           'императрицы': 10,
#           'марии': 6,
#           'феодоровны': 2,
#           'встречая': 5,
#           'важного': 12,
#           'чиновного': 1,
#           'князя': 439,
#           'василия': 32,
#           'первого': 50,
#           'приехавшего': 4,
#           'на': 6796,
#           'ее': 1700,
#           'вечер': 83,
#           'кашляла': 3,
#           'несколько': 404,
#           'дней': 51,
#           'у': 1297,
#           'нее': 375,
#           'был': 1584,
#           'грипп': 2,
#           'как': 4137,
#           'она': 2752,
#           'тогда': 279,
#           'новое': 65,
#           'слово': 115,
#           'употреблявшееся': 1,
#           'только': 1621,
#           'редкими': 5,
#           'записочках': 1,
#           'разосланных': 1,
#           'утром': 52,
#           'с': 5962,
#           'красным': 34,
#           'лакеем': 4,
#           'было': 2519,
#           'написано': 14,
#           'без': 407,
#           'различия': 7,
#           'во': 639,
#           'всех': 578,
#           'а': 2202,
#           'или': 790,
#           'отвечал': 256,
#           'нисколько': 26,
#           'не': 8781,
#           'смутясь': 1,
#           'такою': 28,
#           'встречей': 1,
#           'вошедший': 9,
#           'князь': 1354,
#           'придворном': 6,
#           'шитом': 4,
#           'мундире': 42,
#           'чулках': 9,
#           'башмаках': 7,
#           'при': 507,
#           'звездах': 3,
#           'светлым': 4,
#           'выражением': 98,
#           'плоского': 1,
#           'лица': 249,
#           'он': 7493,
#           'говорил': 658,
#           'изысканном': 1,
#           'французском': 13,
#           'языке': 12,
#           'котором': 258,
#           'говорили': 244,
#           'но': 2782,
#           'думали': 30,
#           'наши': 76,
#           'деды': 1,
#           'теми': 35,
#           'тихими': 9,
#           'покровительственными': 1,
#           'интонациями': 3,
#           'которые': 682,
#           'свойственны': 1,
#           'состаревшемуся': 1,
#           'свете': 82,
#           'дворе': 48,
#           'значительному': 1,
#           'человеку': 56,
#           'подошел': 193,
#           'анне': 17,
#           'павловне': 13,
#           'поцеловал': 53,
#           'руку': 333,
#           'подставив': 3,
#           'ей': 664,
#           'свою': 404,
#           'надушенную': 2,
#           'сияющую': 2,
#           'лысину': 3,
#           'покойно': 12,
#           'уселся': 7,
#           'диване': 27,
#           'успокойте': 1,
#           'друга': 157,
#           'сказал': 2016,
#           'изменяя': 13,
#           'голоса': 122,
#           'тоном': 44,
#           'из': 1887,
#           'за': 1951,
#           'приличия': 8,
#           'участия': 22,
#           'просвечивало': 1,
#           'равнодушие': 3,
#           'даже': 283,
#           'насмешка': 3,
#           'можно': 216,
#           'быть': 773,
#           'здоровой': 2,
#           'когда': 1145,
#           'нравственно': 18,
#           'страдаешь': 2,
#           'разве': 94,
#           'оставаться': 32,
#           'спокойною': 2,
#           'наше': 49,
#           'время': 731,
#           'есть': 543,
#           'человека': 365,
#           'чувство': 198,
#           'сказала': 715,
#           'вы': 1098,
#           'весь': 144,
#           'меня': 616,
#           'надеюсь': 26,
#           'праздник': 13,
#           'английского': 7,
#           'посланника': 5,
#           'нынче': 133,
#           'середа': 2,
#           'мне': 803,
#           'надо': 459,
#           'показаться': 4,
#           'там': 271,
#           'дочь': 66,
#           'заедет': 1,
#           'мной': 64,
#           'повезет': 2,
#           'я': 3108,
#           'думала': 129,
#           'что': 8367,
#           'нынешний': 14,
#           'отменен': 1,
#           'ежели': 479,
#           'бы': 1508,
#           'знали': 60,
#           'этого': 804,
#           'хотите': 59,
#           'отменили': 1,
#           'по': 1972,
#           'привычке': 24,
#           'заведенные': 1,
#           'часы': 26,
#           'говоря': 85,
#           'вещи': 43,
#           'которым': 165,
#           'хотел': 251,
#           'чтобы': 998,
#           'верили': 10,
#           'вам': 344,
#           'сказать': 264,
#           'холодным': 17,
#           'скучающим': 2,
#           'ы': 23,
#           'ф': 30,
#           'василий': 166,
#           'всегда': 394,
#           'лениво': 10,
#           'актер': 1,
#           'говорит': 181,
#           'роль': 33,
#           'старой': 35,
#           'пиесы': 2,
#           'напротив': 102,
#           'несмотря': 261,
#           'свои': 297,
#           'сорок': 13,
#           'лет': 102,
#           'была': 913,
#           'преисполнена': 2,
#           'оживления': 7,
#           'порывов': 2,
#           'энтузиасткой': 2,
#           'сделалось': 33,
#           'общественным': 1,
#           'положением': 17,
#           'иногда': 130,
#           'того': 924,
#           'хотелось': 89,
#           'обмануть': 16,
#           'ожиданий': 1,
#           'людей': 461,
#           'знавших': 4,
#           'делалась': 1,
#           'сдержанная': 2,
#           'улыбка': 47,
#           'игравшая': 1,
#           'постоянно': 52,
#           'лице': 169,
#           'анны': 56,
#           'павловны': 40,
#           'хотя': 219,
#           'шла': 39,
#           'отжившим': 1,
#           'чертам': 2,
#           'выражала': 7,
#           'избалованных': 1,
#           'детей': 44,
#           'постоянное': 2,
#           'сознание': 52,
#           'своего': 416,
#           'милого': 5,
#           'недостатка': 4,
#           'от': 1773,
#           'которого': 348,
#           'хочет': 76,
#           'может': 475,
#           'находит': 8,
#           'нужным': 22,
#           'исправляться': 1,
#           'середине': 79,
#           'разговора': 52,
#           'про': 313,
#           'политические': 9,
#           'действия': 47,
#           'разгорячилась': 1,
#           'ах': 198,
#           'говорите': 47,
#           'австрию': 5,
#           'ничего': 574,
#           'понимаю': 77,
#           'австрия': 5,
#           'никогда': 306,
#           'хотела': 74,
#           'войны': 132,
#           'предает': 1,
#           'нас': 194,
#           'россия': 25,
#           'одна': 190,
#           'должна': 81,
#           'спасительницей': 1,
#           'европы': 25,
#           'наш': 82,
#           'благодетель': 12,
#           'знает': 123,
#           'свое': 286,
#           'высокое': 9,
#           'призвание': 7,
#           'будет': 484,
#           'верен': 3,
#           'ему': 1765,
#           'вот': 623,
#           'одно': 260,
#           'верю': 19,
#           'нашему': 14,
#           'доброму': 3,
#           'чудному': 1,
#           'государю': 91,
#           'предстоит': 4,
#           'величайшая': 3,
#           'мире': 67,
#           'добродетелен': 1,
#           'хорош': 28,
#           'бог': 127,
#           'оставит': 6,
#           'его': 3957,
#           'исполнит': 4,
#           'задавить': 1,
#           'гидру': 1,
#           'революции': 17,
#           'которая': 283,
#           'теперь': 916,
#           'еще': 1158,
#           'ужаснее': 2,
#           'убийцы': 1,
#           'злодея': 6,
#           'мы': 597,
#           'одни': 67,
#           'должны': 104,
#           'искупить': 2,
#           'кровь': 41,
#           'праведника': 1,
#           'кого': 151,
#           'нам': 197,
#           'надеяться': 12,
#           'вас': 392,
#           'спрашиваю': 15,
#           'англия': 1,
#           'своим': 287,
#           'коммерческим': 1,
#           'духом': 13,
#           'поймет': 9,
#           'понять': 121,
#           'всю': 172,
#           'высоту': 7,
#           'души': 61,
#           'императора': 107,
#           'александра': 56,
#           'отказалась': 5,
#           'очистить': 8,
#           'мальту': 1,
#           'видеть': 168,
#           'ищет': 7,
#           'заднюю': 9,
#           'мысль': 105,
#           'наших': 64,
#           'действий': 20,
#           'они': 951,
#           'сказали': 61,
#           'новосильцову': 1,
#           'поняли': 13,
#           'могут': 61,
#           'самоотвержения': 5,
#           'нашего': 47,
#           'который': 641,
#           'для': 1325,
#           'себя': 819,
#           'вс': 982,
#           'блага': 19,
#           'мира': 63,
#           'обещали': 7,
#           'пруссия': 4,
#           'уж': 166,
#           'объявила': 6,
#           'бонапарте': 59,
#           'непобедим': 1,
#           'вся': 141,
#           'европа': 7,
#           'против': 175,
#           'него': 914,
#           'ни': 890,
#           'одном': 60,
#           'слове': 21,
#           'гарденбергу': 1,
#           'гаугвицу': 1,
#           'одного': 223,
#           'бога': 73,
#           'высокую': 3,
#           'судьбу': 9,
#           'спасет': 5,
#           'европу': 8,
#           'вдруг': 500,
#           'остановилась': 59,
#           'улыбкою': 5,
#           'насмешки': 15,
#           'над': 291,
#           'своею': 44,
#           'горячностью': 8,
#           'думаю': 86,
#           'улыбаясь': 179,
#           'послали': 6,
#           'вместо': 71,
#           'винценгероде': 3,
#           'взяли': 30,
#           'приступом': 1,
#           'согласие': 13,
#           'прусского': 4,
#           'короля': 16,
#           'красноречивы': 1,
#           'дадите': 2,
#           'чаю': 29,
#           'сейчас': 154,
#           'прибавила': 34,
#           'опять': 619,
#           'успокоиваясь': 4,
#           'два': 287,
#           'очень': 549,
#           'интересные': 1,
#           'лучших': 17,
#           'фамилий': 2,
#           'франции': 28,
#           'это': 2586,
#           'один': 492,
#           'хороших': 6,
#           'эмигрантов': 1,
#           'настоящих': 8,
#           'потом': 304,
#           'знаете': 123,
#           'этот': 613,
#           'глубокий': 7,
#           'ум': 28,
#           'принят': 11,
#           'государем': 27,
#           'рад': 68,
#           'буду': 84,
#           'скажите': 48,
#           'прибавил': 105,
#           'будто': 479,
#           'вспомнив': 9,
#           'то': 3728,
#           'особенно': 167,
#           'небрежно': 13,
#           'о': 1948,
#           'чем': 637,
#           'спрашивал': 71,
#           'главною': 2,
#           'целью': 47,
#           'посещения': 11,
#           'правда': 107,
#           'желает': 18,
#           'назначения': 8,
#           'барона': 1,
#           'функе': 3,
#           'первым': 16,
#           'секретарем': 3,
#           'вену': 10,
#           'желал': 68,
#           'определить': 10,
#           'сына': 115,
#           'место': 136,
#           'которое': 363,
#           'через': 320,
#           'императрицу': 4,
#           'марию': 2,
#           'феодоровну': 1,
#           'старались': 22,
#           'доставить': 7,
#           'барону': 5,
#           'почти': 173,
#           'закрыла': 12,
#           'глаза': 423,
#           'знак': 32,
#           'кто': 422,
#           'другой': 411,
#           'судить': 27,
#           'угодно': 29,
#           'нравится': 14,
#           'императрице': 4,
#           'грустным': 15,
#           'сухим': 5,
#           'назвала': 3,
#           'лицо': 502,
#           'представило': 3,
#           'глубокое': 3,
#           'искреннее': 1,
#           'выражение': 154,
#           'преданности': 10,
#           'уважения': 12,
#           'соединенное': 1,
#           'грустью': 13,
#           'ней': 427,
#           'бывало': 35,
#           'каждый': 122,
#           'раз': 459,
#           'разговоре': 10,
#           'упоминала': 2,
#           'своей': 543,
#           'высокой': 14,
#           'покровительнице': 2,
#           'величество': 44,
#           'изволила': 3,
#           'оказать': 4,
#           'взгляд': 111,
#           'подернулся': 1,
#           'равнодушно': 13,
#           'замолк': 12,
#           'свойственною': 6,
#           'придворною': 2,
#           'женскою': 2,
#           'ловкостью': 5,
#           'быстротою': 4,
#           'такта': 5,
#           'захотела': 1,
#           'щелконуть': 1,
#           'дерзнул': 1,
#           'отозваться': 2,
#           'рекомендованном': 1,
#           'же': 1821,
#           'утешить': 5,
#           'ли': 529,
#           'ваша': 35,
#           'тех': 269,
#           'пор': 133,
#           'выезжает': 3,
#           'наклонился': 4,
#           'признательности': 1,
#           'часто': 123,
#           'продолжала': 49,
#           'после': 546,
#           'минутного': 8,
#           'молчания': 23,
#           'подвигаясь': 6,
#           'князю': 176,
#           'ласково': 30,
#           'выказывая': 12,
#           'этим': 188,
#           'светские': 3,
#           'разговоры': 31,
#           'кончены': 5,
#           'начинается': 7,
#           'задушевный': 2,
#           'несправедливо': 10,
#           'распределяется': 1,
#           'счастие': 33,
#           'жизни': 389,
#           'судьба': 30,
#           'дала': 15,
#           'таких': 60,
#           'двух': 131,
#           'славных': 1,
#           'исключая': 11,
#           'анатоля': 62,
#           'вашего': 28,
#           'меньшого': 4,
#           'люблю': 114,
#           'вставила': 2,
#           'безапелляционно': 1,
#           'приподняв': 12,
#           'брови': 18,
#           'прелестных': 1,
#           'право': 90,
#           'менее': 85,
#           'цените': 1,
#           'их': 791,
#           'потому': 561,
#           'стоите': 5,
#           'улыбнулась': 46,
#           'восторженною': 3,
#           'улыбкой': 221,
#           'перестаньте': 7,
#           'шутить': 15,
#           'серьезно': 40,
#           'поговорить': 29,
#           'вами': 84,
#           'недовольна': 4,
#           'вашим': 22,
#           'меньшим': 1,
#           'сыном': 33,
#           'между': 371,
#           'нами': 48,
#           'будь': 15,
#           'сказано': 32,
#           'приняло': 19,
#           'грустное': 4,
#           'нем': 238,
#           'величества': 13,
#           'жалеют': 4,
#           'молча': 124,
#           'значительно': 27,
#           'глядя': 241,
#           'ждала': 18,
#           'ответа': 33,
#           'поморщился': 15,
#           'чтоб': 133,
#           'делал': 89,
#           'наконец': 109,
#           'сделал': 144,
#           'воспитания': 6,
#           'все': 1852,
#           'отец': 137,
#           'оба': 77,
#           'вышли': 45,
#           'ипполит': 40,
#           'крайней': 22,
#           'мере': 46,
#           'покойный': 2,
#           'дурак': 31,
#           'анатоль': 141,
#           'беспокойный': 3,
#           'различие': 9,
#           'более': 426,
#           'неестественно': 19,
#           'одушевленно': 1,
#           'обыкновенно': 45,
#           'этом': 350,
#           'резко': 8,
#           'сложившихся': 1,
#           'около': 117,
#           'рта': 14,
#           'морщинах': 2,
#           'неожиданно': 69,
#           'грубое': 2,
#           'неприятное': 15,
#           'зачем': 132,
#           'родятся': 2,
#           'дети': 42,
#           'были': 906,
#           'могла': 192,
#           'упрекнуть': 5,
#           'задумчиво': 16,
#           'поднимая': 31,
#           'мои': 52,
#           'крест': 17,
#           'себе': 675,
#           'объясняю': 2,
#           'помолчал': 26,
#           'выражая': 13,
#           'жестом': 40,
#           'покорность': 5,
#           'жестокой': 4,
#           'судьбе': 4,
#           'задумалась': 7,
#           'женить': 8,
#           'блудного': 1,
#           'говорят': 132,
#           'старые': 27,
#           'девицы': 8,
#           'чувствую': 19,
#           'собою': 110,
#           'этой': 313,
#           'слабости': 19,
#           'несчастлива': 3,
#           'отцом': 35,
#           'болконская': 6,
#           'светским': 3,
#           'людям': 51,
#           'быстротой': 12,
#           'соображения': 22,
#           'памяти': 15,
#           'показал': 34,
#           'движением': 52,
#           'головы': 49,
#           'принял': 49,
#           'соображению': 1,
#           'эти': 444,
#           'сведения': 15,
#           'нет': 637,
#           'стоит': 73,
#           'год': 50,
#           'видимо': 210,
#           'силах': 47,
#           'удерживать': 13,
#           'печальный': 3,
#           'ход': 28,
#           'своих': 266,
#           'мыслей': 49,
#           'пять': 51,
#           'если': 208,
#           'пойдет': 17,
#           'богата': 5,
#           'княжна': 570,
#           'богат': 9,
#           'скуп': 2,
#           'живет': 19,
#           'деревне': 55,
#           'известный': 21,
#           'болконский': 83,
#           'отставленный': 1,
#           'покойном': 5,
#           'императоре': 4,
#           'прозванный': 1,
#           'прусским': 2,
#           'королем': 10,
#           'умный': 16,
#           'человек': 501,
#           'со': 387,
#           'странностями': 1,
#           'тяжелый': 4,
#           'брат': 75,
#           'недавно': 23,
#           'женился': 15,
#           'мейнен': 1,
#           'адъютант': 129,
#           'кутузова': 139,
#           'взяв': 58,
#           'собеседницу': 4,
#           'пригибая': 3,
#           'почему': 109,
#           'книзу': 12,
#           'вернейший': 1,
#           'староста': 16,
#           'донесенья': 1,
#           'покой': 1,
#           'ер': 1,
#           'п': 38,
#           'хорошей': 2,
#           'фамилии': 7,
#           'нужно': 263,
#           'свободными': 8,
#           'фамильярными': 1,
#           'грациозными': 1,
#           'движениями': 16,
#           'отличали': 1,
#           'взял': 132,
#           'фрейлину': 1,
#           'поцеловав': 9,
#           'помахал': 3,
#           'фрейлинскою': 1,
#           'рукой': 120,
#           'развалившись': 2,
#           'креслах': 2,
#           'сторону': 89,
#           'соображая': 12,
#           'поговорю': 3,
#           'уладится': 1,
#           'гостиная': 2,
#           'начала': 71,
#           'понемногу': 16,
#           'наполняться': 1,
#           'приехала': 28,
#           'высшая': 8,
#           'знать': 123,
#           'петербурга': 41,
#           'люди': 323,
#           'самые': 73,
#           'разнородные': 2,
#           'возрастам': 1,
#           'характерам': 1,
#           'одинаковые': 1,
#           'обществу': 13,
#           'каком': 36,
#           'жили': 17,
#           'красавица': 13,
#           'элен': 165,
#           'заехавшая': 1,
#           'ним': 491,
#           'вместе': 250,
#           'ехать': 146,
#           'шифре': 1,
#           'бальном': 2,
#           'платье': 89,
#           'молодая': 13,
#           'маленькая': 54,
#           'княгиня': 116,
#           'прошлую': 4,
#           'зиму': 10,
#           'вышедшая': 3,
#           'замуж': 39,
#           'выезжавшая': 1,
#           'большой': 85,
#           'свет': 47,
#           'причине': 10,
#           'беременности': 4,
#           'ездившая': 2,
#           'небольшие': 5,
#           'вечера': 68,
#           'приехал': 145,
#           'сын': 91,
#           'мортемаром': 1,
#           'представил': 11,
#           'аббат': 10,
#           'морио': 4,
#           'многие': 31,
#           'другие': 167,
#           'видали': 12,
#           'знакомы': 6,
#           'приезжавшим': 1,
#           'гостям': 6,
#           'весьма': 81,
#           'подводила': 3,
#           'маленькой': 46,
#           'старушке': 1,
#           'высоких': 4,
#           'бантах': 1,
#           'выплывшей': 1,
#           'комнаты': 151,
#           'скоро': 114,
#           'стали': 134,
#           'приезжать': 4,
#           'гости': 42,
#           'называла': 18,
#           'имени': 27,
#           'медленно': 36,
#           'переводя': 9,
#           'гостя': 13,
#           'отходила': 3,
#           'совершали': 2,
#           'обряд': 3,
#           'приветствования': 1,
#           'никому': 68,
#           'неизвестной': 9,
#           'неинтересной': 1,
#           'ненужной': 1,
#           'тетушки': 6,
#           'торжественным': 10,
#           'участием': 7,
#           'следила': 11,
#           'приветствиями': 1,
#           'молчаливо': 5,
#           'одобряя': 6,
#           'каждому': 19,
#           'одних': 19,
#           'выражениях': 4,
#           'здоровье': 57,
#           'своем': 170,
#           'слава': 47,
#           'богу': 83,
#           'лучше': 144,
#           'подходившие': 3,
#           'поспешности': 7,
#           'чувством': 41,
#           'облегчения': 3,
#           'исполненной': 1,
#           'тяжелой': 6,
#           'обязанности': 16,
#           'отходили': 5,
#           'старушки': 4,
#           'разу': 31,
#           'подойти': 8,
#           'работой': 13,
#           'золотом': 7,
#           'бархатном': 3,
#           'мешке': 2,
#           'хорошенькая': 9,
#           'чуть': 80,
#           'черневшимися': 1,
#           'усиками': 10,
#           'верхняя': 7,
#           'губка': 8,
#           'коротка': 1,
#           'зубам': 1,
#           'тем': 610,
#           'милее': 2,
#           'открывалась': 3,
#           'вытягивалась': 1,
#           'опускалась': 4,
#           'нижнюю': 9,
#           'бывает': 91,
#           'вполне': 66,
#           'привлекательных': 1,
#           'женщин': 42,
#           'недостаток': 10,
#           'короткость': 1,
#           'губы': 39,
#           'полуоткрытый': 1,
#           'рот': 32,
#           'казались': 37,
#           'особенною': 5,
#           'собственно': 6,
#           'красотой': 15,
#           'всем': 263,
#           'весело': 125,
#           'смотреть': 59,
#           'эту': 256,
#           'полную': 13,
#           'здоровья': 3,
#           'живости': 1,
#           'хорошенькую': 5,
#           'будущую': 8,
#           'мать': 94,
#           'легко': 71,
#           'переносившую': 1,
#           'положение': 136,
#           'старикам': 3,
#           'мрачным': 7,
#           'молодым': 26,
#           'смотревшим': 5,
#           'казалось': 317,
#           'сами': 79,
#           'делаются': 8,
#           'похожи': 6,
#           'побыв': 1,
#           'поговорив': 8,
#           'времени': 230,
#           'видел': 263,
#           'каждом': 36,
#           'светлую': 4,
#           'улыбочку': 1,
#           'блестящие': 20,
#           'белые': 23,
#           'зубы': 27,
#           'виднелись': 34,
#           'беспрестанно': 73,
#           'тот': 293,
#           'думал': 309,
#           'любезен': 4,
#           'переваливаясь': 7,
#           'маленькими': 13,
#           'быстрыми': 36,
#           'шажками': 2,
#           'обошла': 2,
#           'стол': 47,
#           'рабочею': 1,
#           'сумочкою': 1,
#           'руке': 55,
#           'оправляя': 6,
#           'села': 45,
#           'диван': 29,
#           'серебряного': 1,
#           'самовара': 3,
#           'делала': 31,
#           'окружавших': 8,
#           'развертывая': 6,
#           'свой': 179,
#           'ридикюль': 6,
#           'обращаясь': 105,
#           'ко': 114,
#           'смотрите': 19,
#           'обратилась': 40,
#           'хозяйке': 2,
#           'развела': 1,
#           'руками': 128,
#           'показать': 35,
#           'кружевах': 2,
#           'серенькое': 2,
#           'изящное': 1,
#           'немного': 49,
#           'ниже': 16,
#           'грудей': 1,
#           'опоясанное': 1,
#           'широкою': 1,
#           'лентой': 4,
#           'отвечала': 75,
#           'генералу': 51,
#           'василию': 5,
#           'дожидаясь': 20,
#           'дочери': 66,
#           'красивой': 15,
#           'тихо': 85,
#           'вскоре': 24,
#           'княгини': 24,
#           'вошел': 135,
#           'массивный': 1,
#           'толстый': 19,
#           'молодой': 108,
#           'стриженою': 1,
#           'головой': 157,
#           'очках': 8,
#           'светлых': 2,
#           'панталонах': 7,
#           'тогдашней': 3,
#           'моде': 6,
#           'высоким': 11,
#           'жабо': 3,
#           'коричневом': 1,
#           'фраке': 9,
#           'незаконный': 7,
#           'знаменитого': 5,
#           'екатерининского': 3,
#           'вельможи': 11,
#           'графа': 189,
#           'безухого': 21,
#           'умиравшего': 1,
#           'москве': 211,
#           'нигде': 16,
#           'служил': 16,
#           'границы': 12,
#           'где': 457,
#           'воспитывался': 2,
#           'обществе': 36,
#           'приветствовала': 1,
#           'поклоном': 5,
#           'относящимся': 1,
#           'самой': 82,
#           'низшей': 1,
#           'иерархии': 2,
#           'салоне': 5,
#           'низшее': 1,
#           'своему': 156,
#           'сорту': 1,
#           'приветствие': 2,
#           'виде': 42,
#           'вошедшего': 3,
#           'пьера': 475,
#           'изобразилось': 1,
#           'беспокойство': 18,
#           'страх': 58,
#           'подобный': 3,
#           'тому': 302,
#           'выражается': 11,
#           'чего': 262,
#           'нибудь': 339,
#           'слишком': 117,
#           'огромного': 21,
#           'несвойственного': 1,
#           'месту': 27,
#           'действительно': 93,
#           'пьер': 1401,
#           'больше': 331,
#           ...}),
#  'n2': Counter({'л н': 5,
#           'н толстой': 1,
#           'толстой война': 1,
#           'война и': 5,
#           'и мир': 4,
#           'мир том': 3,
#           'том первый': 1,
#           'первый часть': 1,
#           'часть первая': 5,
#           'первая е': 1,
#           'е к': 1,
#           'к поместья': 1,
#           'поместья й': 1,
#           'й й': 444,
#           'й к': 57,
#           'к к': 11,
#           'к мой': 1,
#           'мой верный': 2,
#           'верный раб': 3,
#           'раб см': 1,
#           'см сноски': 16,
#           'сноски в': 16,
#           'в конце': 52,
#           'конце части': 16,
#           'части ну': 1,
#           'ну здравствуйте': 2,
#           'здравствуйте здравствуйте': 1,
#           'здравствуйте садитесь': 1,
#           'садитесь и': 1,
#           'и рассказывайте': 1,
#           'рассказывайте так': 1,
#           'так говорила': 3,
#           'говорила в': 3,
#           'в июле': 2,
#           'июле года': 1,
#           'года известная': 1,
#           'известная анна': 1,
#           'анна павловна': 99,
#           'павловна шерер': 4,
#           'шерер фрейлина': 1,
#           'фрейлина и': 1,
#           'и приближенная': 1,
#           'приближенная императрицы': 1,
#           'императрицы марии': 2,
#           'марии феодоровны': 2,
#           'феодоровны встречая': 1,
#           'встречая важного': 1,
#           'важного и': 1,
#           'и чиновного': 1,
#           'чиновного князя': 1,
#           'князя василия': 28,
#           'василия первого': 1,
#           'первого приехавшего': 1,
#           'приехавшего на': 1,
#           'на ее': 49,
#           'ее вечер': 1,
#           'вечер анна': 3,
#           'павловна кашляла': 1,
#           'кашляла несколько': 1,
#           'несколько дней': 24,
#           'дней у': 1,
#           'у нее': 41,
#           'нее был': 3,
#           'был грипп': 1,
#           'грипп как': 1,
#           'как она': 87,
#           'она говорила': 27,
#           'говорила грипп': 1,
#           'грипп был': 1,
#           'был тогда': 4,
#           'тогда новое': 1,
#           'новое слово': 1,
#           'слово употреблявшееся': 1,
#           'употреблявшееся только': 1,
#           'только редкими': 1,
#           'редкими в': 1,
#           'в записочках': 1,
#           'записочках разосланных': 1,
#           'разосланных утром': 1,
#           'утром с': 3,
#           'с красным': 18,
#           'красным лакеем': 1,
#           'лакеем было': 1,
#           'было написано': 10,
#           'написано без': 1,
#           'без различия': 3,
#           'различия во': 1,
#           'во всех': 54,
#           'всех а': 1,
#           'а или': 1,
#           'или й': 2,
#           'й отвечал': 6,
#           'отвечал нисколько': 1,
#           'нисколько не': 16,
#           'не смутясь': 1,
#           'смутясь такою': 1,
#           'такою встречей': 1,
#           'встречей вошедший': 1,
#           'вошедший князь': 1,
#           'князь в': 8,
#           'в придворном': 6,
#           'придворном шитом': 1,
#           'шитом мундире': 1,
#           'мундире в': 6,
#           'в чулках': 5,
#           'чулках башмаках': 2,
#           'башмаках при': 1,
#           'при звездах': 1,
#           'звездах с': 1,
#           'с светлым': 1,
#           'светлым выражением': 1,
#           'выражением плоского': 1,
#           'плоского лица': 1,
#           'лица он': 7,
#           'он говорил': 114,
#           'говорил на': 4,
#           'на том': 49,
#           'том изысканном': 1,
#           'изысканном французском': 1,
#           'французском языке': 6,
#           'языке на': 1,
#           'на котором': 64,
#           'котором не': 2,
#           'не только': 211,
#           'только говорили': 3,
#           'говорили но': 5,
#           'но и': 88,
#           'и думали': 3,
#           'думали наши': 1,
#           'наши деды': 1,
#           'деды и': 1,
#           'и с': 335,
#           'с теми': 16,
#           'теми тихими': 1,
#           'тихими покровительственными': 1,
#           'покровительственными интонациями': 1,
#           'интонациями которые': 1,
#           'которые свойственны': 1,
#           'свойственны состаревшемуся': 1,
#           'состаревшемуся в': 1,
#           'в свете': 23,
#           'свете и': 4,
#           'и при': 32,
#           'при дворе': 6,
#           'дворе значительному': 1,
#           'значительному человеку': 1,
#           'человеку он': 2,
#           'он подошел': 20,
#           'подошел к': 156,
#           'к анне': 9,
#           'анне павловне': 13,
#           'павловне поцеловал': 1,
#           'поцеловал ее': 19,
#           'ее руку': 30,
#           'руку подставив': 1,
#           'подставив ей': 2,
#           'ей свою': 4,
#           'свою надушенную': 2,
#           'надушенную и': 1,
#           'и сияющую': 1,
#           'сияющую лысину': 1,
#           'лысину и': 3,
#           'и покойно': 2,
#           'покойно уселся': 2,
#           'уселся на': 2,
#           'на диване': 24,
#           'диване и': 3,
#           'и успокойте': 1,
#           'успокойте друга': 1,
#           'друга сказал': 1,
#           'сказал он': 488,
#           'он не': 482,
#           'не изменяя': 10,
#           'изменяя голоса': 2,
#           'голоса и': 19,
#           'и тоном': 1,
#           'тоном в': 2,
#           'в котором': 165,
#           'котором из': 1,
#           'из за': 137,
#           'за приличия': 1,
#           'приличия и': 2,
#           'и участия': 1,
#           'участия просвечивало': 1,
#           'просвечивало равнодушие': 1,
#           'равнодушие и': 2,
#           'и даже': 82,
#           'даже насмешка': 1,
#           'насмешка как': 1,
#           'как можно': 47,
#           'можно быть': 4,
#           'быть здоровой': 1,
#           'здоровой когда': 1,
#           'когда нравственно': 1,
#           'нравственно страдаешь': 1,
#           'страдаешь разве': 1,
#           'разве можно': 8,
#           'можно оставаться': 1,
#           'оставаться спокойною': 1,
#           'спокойною в': 1,
#           'в наше': 14,
#           'наше время': 9,
#           'время когда': 19,
#           'когда есть': 1,
#           'есть у': 8,
#           'у человека': 3,
#           'человека чувство': 1,
#           'чувство сказала': 1,
#           'сказала анна': 31,
#           'павловна вы': 1,
#           'вы весь': 1,
#           'весь вечер': 6,
#           'вечер у': 2,
#           'у меня': 116,
#           'меня надеюсь': 1,
#           'надеюсь а': 1,
#           'а праздник': 1,
#           'праздник английского': 1,
#           'английского посланника': 1,
#           'посланника нынче': 1,
#           'нынче середа': 1,
#           'середа мне': 1,
#           'мне надо': 18,
#           'надо показаться': 1,
#           'показаться там': 1,
#           'там сказал': 1,
#           'сказал князь': 156,
#           'князь дочь': 1,
#           'дочь заедет': 1,
#           'заедет за': 1,
#           'за мной': 9,
#           'мной и': 2,
#           'и повезет': 2,
#           'повезет меня': 1,
#           'меня я': 17,
#           'я думала': 10,
#           'думала что': 12,
#           'что нынешний': 2,
#           'нынешний праздник': 1,
#           'праздник отменен': 1,
#           'отменен к': 1,
#           'к а': 20,
#           'а ежели': 18,
#           'ежели бы': 188,
#           'бы знали': 1,
#           'знали что': 22,
#           'что вы': 112,
#           'вы этого': 6,
#           'этого хотите': 3,
#           'хотите праздник': 1,
#           'праздник бы': 1,
#           'бы отменили': 1,
#           'отменили сказал': 1,
#           'князь по': 1,
#           'по привычке': 11,
#           'привычке как': 1,
#           'как заведенные': 1,
#           'заведенные часы': 1,
#           'часы говоря': 1,
#           'говоря вещи': 1,
#           'вещи которым': 1,
#           'которым он': 38,
#           'он и': 163,
#           'и не': 725,
#           'не хотел': 45,
#           'хотел чтобы': 3,
#           'чтобы верили': 1,
#           'верили й': 1,
#           'й а': 112,
#           'а й': 106,
#           'к как': 1,
#           'как вам': 9,
#           'вам сказать': 11,
#           'сказать сказал': 1,
#           'князь холодным': 1,
#           'холодным скучающим': 1,
#           'скучающим тоном': 1,
#           'тоном й': 1,
#           'й ы': 10,
#           'ы й': 9,
#           'ы ф': 3,
#           'ф князь': 1,
#           'князь василий': 153,
#           'василий говорил': 1,
#           'говорил всегда': 4,
#           'всегда лениво': 1,
#           'лениво как': 1,
#           'как актер': 1,
#           'актер говорит': 1,
#           'говорит роль': 1,
#           'роль старой': 1,
#           'старой пиесы': 1,
#           'пиесы анна': 1,
#           'шерер напротив': 1,
#           'напротив несмотря': 1,
#           'несмотря на': 259,
#           'на свои': 17,
#           'свои сорок': 1,
#           'сорок лет': 1,
#           'лет была': 1,
#           'была преисполнена': 2,
#           'преисполнена оживления': 1,
#           'оживления и': 3,
#           'и порывов': 1,
#           'порывов быть': 1,
#           'быть энтузиасткой': 1,
#           'энтузиасткой сделалось': 1,
#           'сделалось ее': 1,
#           'ее общественным': 1,
#           'общественным положением': 1,
#           'положением и': 5,
#           'и иногда': 13,
#           'иногда когда': 5,
#           'когда ей': 6,
#           'ей даже': 2,
#           'даже того': 1,
#           'того не': 10,
#           'не хотелось': 14,
#           'хотелось она': 1,
#           'она чтобы': 4,
#           'чтобы не': 78,
#           'не обмануть': 1,
#           'обмануть ожиданий': 1,
#           'ожиданий людей': 1,
#           'людей знавших': 3,
#           'знавших ее': 1,
#           'ее делалась': 1,
#           'делалась энтузиасткой': 1,
#           'энтузиасткой сдержанная': 1,
#           'сдержанная улыбка': 1,
#           'улыбка игравшая': 1,
#           'игравшая постоянно': 1,
#           'постоянно на': 1,
#           'на лице': 67,
#           'лице анны': 5,
#           'анны павловны': 40,
#           'павловны хотя': 1,
#           'хотя и': 78,
#           'не шла': 2,
#           'шла к': 5,
#           'к ее': 24,
#           'ее отжившим': 1,
#           'отжившим чертам': 1,
#           'чертам выражала': 1,
#           'выражала как': 1,
#           'как у': 21,
#           'у избалованных': 1,
#           'избалованных детей': 1,
#           'детей постоянное': 1,
#           'постоянное сознание': 1,
#           'сознание своего': 3,
#           'своего милого': 1,
#           'милого недостатка': 1,
#           'недостатка от': 1,
#           'от которого': 11,
#           'которого она': 28,
#           'она не': 230,
#           'не хочет': 26,
#           'хочет не': 2,
#           'не может': 198,
#           'может и': 9,
#           'не находит': 1,
#           'находит нужным': 1,
#           'нужным исправляться': 1,
#           'исправляться в': 1,
#           'в середине': 65,
#           'середине разговора': 6,
#           'разговора про': 1,
#           'про политические': 1,
#           'политические действия': 1,
#           'действия анна': 1,
#           'павловна разгорячилась': 1,
#           'разгорячилась ах': 1,
#           'ах не': 4,
#           'не говорите': 17,
#           'говорите мне': 7,
#           'мне про': 5,
#           'про австрию': 1,
#           'австрию я': 1,
#           'я ничего': 46,
#           'ничего не': 343,
#           'не понимаю': 45,
#           'понимаю может': 2,
#           'может быть': 239,
#           'быть но': 7,
#           'но австрия': 1,
#           'австрия никогда': 1,
#           'никогда не': 204,
#           'не хотела': 15,
#           'хотела и': 4,
#           'хочет войны': 1,
#           'войны она': 2,
#           'она предает': 1,
#           'предает нас': 1,
#           'нас россия': 1,
#           'россия одна': 1,
#           'одна должна': 1,
#           'должна быть': 10,
#           'быть спасительницей': 1,
#           'спасительницей европы': 1,
#           'европы наш': 1,
#           'наш благодетель': 1,
#           'благодетель знает': 1,
#           'знает свое': 1,
#           'свое высокое': 1,
#           'высокое призвание': 1,
#           'призвание и': 2,
#           'и будет': 12,
#           'будет верен': 1,
#           'верен ему': 1,
#           'ему вот': 1,
#           'вот одно': 2,
#           'одно во': 1,
#           'во что': 13,
#           'что я': 238,
#           'я верю': 8,
#           'верю нашему': 1,
#           'нашему доброму': 1,
#           'доброму и': 1,
#           'и чудному': 1,
#           'чудному государю': 1,
#           'государю предстоит': 1,
#           'предстоит величайшая': 1,
#           'величайшая роль': 1,
#           'роль в': 3,
#           'в мире': 38,
#           'мире и': 8,
#           'и он': 322,
#           'он так': 71,
#           'так добродетелен': 1,
#           'добродетелен и': 1,
#           'и хорош': 1,
#           'хорош что': 1,
#           'что бог': 8,
#           'бог не': 5,
#           'не оставит': 1,
#           'оставит его': 1,
#           'его и': 183,
#           'он исполнит': 1,
#           'исполнит свое': 1,
#           'свое призвание': 2,
#           'призвание задавить': 1,
#           'задавить гидру': 1,
#           'гидру революции': 1,
#           'революции которая': 1,
#           'которая теперь': 4,
#           'теперь еще': 6,
#           'еще ужаснее': 2,
#           'ужаснее в': 1,
#           'в лице': 32,
#           'лице этого': 2,
#           'этого убийцы': 1,
#           'убийцы и': 1,
#           'и злодея': 1,
#           'злодея мы': 1,
#           'мы одни': 3,
#           'одни должны': 1,
#           'должны искупить': 1,
#           'искупить кровь': 1,
#           'кровь праведника': 1,
#           'праведника на': 1,
#           'на кого': 13,
#           'кого нам': 1,
#           'нам надеяться': 1,
#           'надеяться я': 1,
#           'я вас': 62,
#           'вас спрашиваю': 7,
#           'спрашиваю англия': 1,
#           'англия с': 1,
#           'с своим': 63,
#           'своим коммерческим': 1,
#           'коммерческим духом': 1,
#           'духом не': 2,
#           'не поймет': 5,
#           'поймет и': 2,
#           'может понять': 7,
#           'понять всю': 2,
#           'всю высоту': 1,
#           'высоту души': 1,
#           'души императора': 1,
#           'императора александра': 22,
#           'александра она': 1,
#           'она отказалась': 2,
#           'отказалась очистить': 1,
#           'очистить мальту': 1,
#           'мальту она': 1,
#           'она хочет': 1,
#           'хочет видеть': 2,
#           'видеть ищет': 1,
#           'ищет заднюю': 1,
#           'заднюю мысль': 1,
#           'мысль наших': 1,
#           'наших действий': 1,
#           'действий что': 1,
#           'что они': 157,
#           'они сказали': 3,
#           'сказали новосильцову': 1,
#           'новосильцову ничего': 1,
#           'ничего они': 1,
#           'они не': 57,
#           'не поняли': 4,
#           'поняли они': 1,
#           'не могут': 16,
#           'могут понять': 2,
#           'понять самоотвержения': 1,
#           'самоотвержения нашего': 1,
#           'нашего императора': 2,
#           'императора который': 1,
#           'который ничего': 2,
#           'хочет для': 2,
#           'для себя': 56,
#           'себя и': 67,
#           'и вс': 80,
#           'вс хочет': 1,
#           'для блага': 6,
#           'блага мира': 1,
#           'мира и': 12,
#           'и что': 399,
#           'они обещали': 1,
#           'обещали ничего': 1,
#           'ничего и': 7,
#           'что обещали': 1,
#           'обещали и': 1,
#           'и того': 18,
#           'не будет': 76,
#           'будет пруссия': 1,
#           'пруссия уж': 1,
#           'уж объявила': 1,
#           'объявила что': 2,
#           'что бонапарте': 7,
#           'бонапарте непобедим': 1,
#           'непобедим и': 1,
#           'что вся': 7,
#           'вся европа': 2,
#           'европа ничего': 1,
#           'может против': 1,
#           'против него': 24,
#           'него и': 92,
#           'и я': 149,
#           'я не': 339,
#           'не верю': 9,
#           'верю ни': 1,
#           'ни в': 42,
#           'в одном': 23,
#           'одном слове': 1,
#           'слове ни': 1,
#           'ни гарденбергу': 1,
#           'гарденбергу ни': 1,
#           'ни гаугвицу': 1,
#           'гаугвицу й': 1,
#           'й и': 96,
#           'верю в': 5,
#           'в одного': 1,
#           'одного бога': 1,
#           'бога и': 5,
#           'и в': 498,
#           'в высокую': 1,
#           'высокую судьбу': 1,
#           'судьбу нашего': 1,
#           'нашего милого': 2,
#           'милого императора': 1,
#           'императора он': 4,
#           'он спасет': 2,
#           'спасет европу': 1,
#           'европу она': 1,
#           'она вдруг': 9,
#           'вдруг остановилась': 5,
#           'остановилась с': 1,
#           'с улыбкою': 4,
#           'улыбкою насмешки': 1,
#           'насмешки над': 6,
#           'над своею': 2,
#           'своею горячностью': 1,
#           'горячностью я': 1,
#           'я думаю': 61,
#           'думаю сказал': 3,
#           'князь улыбаясь': 1,
#           'улыбаясь что': 6,
#           'что ежели': 60,
#           'бы вас': 5,
#           'вас послали': 1,
#           'послали вместо': 1,
#           'вместо нашего': 1,
#           'милого винценгероде': 1,
#           'винценгероде вы': 1,
#           'вы бы': 7,
#           'бы взяли': 1,
#           'взяли приступом': 1,
#           'приступом согласие': 1,
#           'согласие прусского': 1,
#           'прусского короля': 4,
#           'короля вы': 1,
#           'вы так': 12,
#           'так красноречивы': 1,
#           'красноречивы вы': 1,
#           'вы дадите': 2,
#           'дадите мне': 2,
#           'мне чаю': 1,
#           'чаю сейчас': 1,
#           'сейчас прибавила': 1,
#           'прибавила она': 32,
#           'она опять': 13,
#           'опять успокоиваясь': 1,
#           'успокоиваясь нынче': 1,
#           'нынче у': 3,
#           'меня два': 2,
#           'два очень': 1,
#           'очень интересные': 1,
#           'интересные человека': 1,
#           'человека й': 2,
#           'й одна': 1,
#           'одна из': 22,
#           'из лучших': 10,
#           'лучших фамилий': 2,
#           'фамилий франции': 1,
#           'франции это': 1,
#           'это один': 3,
#           'один из': 100,
#           'из хороших': 3,
#           'хороших эмигрантов': 1,
#           'эмигрантов из': 1,
#           'из настоящих': 1,
#           'настоящих и': 1,
#           'и потом': 59,
#           'потом й': 1,
#           'й вы': 2,
#           'вы знаете': 61,
#           'знаете этот': 2,
#           'этот глубокий': 1,
#           'глубокий ум': 3,
#           'ум он': 2,
#           'он был': 258,
#           'был принят': 6,
#           'принят государем': 1,
#           'государем вы': 1,
#           'знаете а': 2,
#           'а я': 107,
#           'я очень': 35,
#           'очень рад': 33,
#           'рад буду': 1,
#           'буду сказал': 1,
#           'князь скажите': 1,
#           'скажите прибавил': 1,
#           'прибавил он': 75,
#           'он как': 62,
#           'как будто': 430,
#           'будто только': 3,
#           'только что': 124,
#           'что вспомнив': 1,
#           'вспомнив что': 3,
#           'что то': 475,
#           'то и': 95,
#           'и особенно': 14,
#           'особенно небрежно': 1,
#           'небрежно тогда': 1,
#           'тогда как': 36,
#           'как то': 32,
#           'то о': 22,
#           'о чем': 80,
#           'чем он': 36,
#           'он спрашивал': 13,
#           'спрашивал было': 1,
#           'было главною': 1,
#           'главною целью': 1,
#           'целью его': 1,
#           'его посещения': 2,
#           'посещения правда': 1,
#           'правда что': 16,
#           'что й': 4,
#           'и желает': 3,
#           'желает назначения': 1,
#           'назначения барона': 1,
#           'барона функе': 1,
#           'функе первым': 1,
#           'первым секретарем': 1,
#           'секретарем в': 1,
#           'в вену': 6,
#           'вену а': 1,
#           'а о': 9,
#           'о князь': 1,
#           'василий желал': 1,
#           'желал определить': 1,
#           'определить сына': 1,
#           'сына на': 4,
#           'на это': 54,
#           'это место': 7,
#           'место которое': 3,
#           'которое через': 1,
#           'через императрицу': 1,
#           'императрицу марию': 2,
#           'марию феодоровну': 1,
#           'феодоровну старались': 1,
#           'старались доставить': 1,
#           'доставить барону': 1,
#           'барону анна': 1,
#           'павловна почти': 1,
#           'почти закрыла': 1,
#           'закрыла глаза': 6,
#           'глаза в': 8,
#           'в знак': 19,
#           'знак того': 4,
#           'того что': 285,
#           'что ни': 24,
#           'ни она': 2,
#           'она ни': 15,
#           'ни кто': 1,
#           'кто другой': 2,
#           'другой не': 3,
#           'могут судить': 1,
#           'судить про': 2,
#           'про то': 17,
#           'то что': 666,
#           'что угодно': 2,
#           'угодно или': 1,
#           'или нравится': 1,
#           'нравится императрице': 1,
#           'императрице й': 1,
#           'и только': 74,
#           'только сказала': 3,
#           'сказала она': 219,
#           'она грустным': 1,
#           'грустным сухим': 1,
#           'сухим тоном': 1,
#           'в то': 227,
#           'то время': 161,
#           'время как': 147,
#           'как анна': 1,
#           'павловна назвала': 1,
#           'назвала императрицу': 1,
#           'императрицу лицо': 1,
#           'лицо ее': 32,
#           'ее вдруг': 8,
#           'вдруг представило': 1,
#           'представило глубокое': 1,
#           'глубокое и': 1,
#           'и искреннее': 1,
#           'искреннее выражение': 1,
#           'выражение преданности': 1,
#           'преданности и': 5,
#           'и уважения': 1,
#           'уважения соединенное': 1,
#           'соединенное с': 1,
#           'с грустью': 10,
#           'грустью что': 1,
#           'что с': 76,
#           'с ней': 76,
#           'ней бывало': 1,
#           'бывало каждый': 1,
#           'каждый раз': 6,
#           'раз когда': 8,
#           'когда она': 67,
#           'она в': 38,
#           'в разговоре': 6,
#           'разговоре упоминала': 1,
#           'упоминала о': 2,
#           'о своей': 28,
#           'своей высокой': 2,
#           'высокой покровительнице': 2,
#           'покровительнице она': 1,
#           'она сказала': 20,
#           'сказала что': 20,
#           'что ее': 31,
#           'ее величество': 1,
#           'величество изволила': 1,
#           'изволила оказать': 1,
#           'оказать барону': 1,
#           'барону функе': 1,
#           'функе и': 1,
#           'и опять': 136,
#           'опять взгляд': 2,
#           'взгляд ее': 4,
#           'ее подернулся': 1,
#           'подернулся грустью': 1,
#           'грустью князь': 1,
#           'князь равнодушно': 1,
#           'равнодушно замолк': 1,
#           'замолк анна': 1,
#           'павловна с': 6,
#           'с свойственною': 6,
#           'свойственною ей': 1,
#           'ей придворною': 1,
#           'придворною и': 1,
#           'и женскою': 1,
#           'женскою ловкостью': 1,
#           'ловкостью и': 1,
#           'и быстротою': 1,
#           'быстротою такта': 1,
#           'такта захотела': 1,
#           'захотела и': 1,
#           'и щелконуть': 1,
#           'щелконуть князя': 1,
#           'князя за': 1,
#           'за то': 79,
#           'что он': 861,
#           'он дерзнул': 1,
#           'дерзнул так': 1,
#           'так отозваться': 1,
#           'отозваться о': 1,
#           'о лице': 1,
#           'лице рекомендованном': 1,
#           'рекомендованном императрице': 1,
#           'императрице и': 1,
#           'то же': 200,
#           'же время': 43,
#           'время утешить': 1,
#           'утешить его': 1,
#           'его а': 11,
#           'а сказала': 4,
#           'она знаете': 1,
#           'знаете ли': 9,
#           'ли что': 27,
#           'что ваша': 2,
#           'ваша дочь': 1,
#           'дочь с': 2,
#           'с тех': 54,
#           'тех пор': 93,
#           'пор как': 36,
#           'как выезжает': 1,
#           'выезжает й': 1,
#           'й князь': 4,
#           'князь наклонился': 1,
#           'наклонился в': 1,
#           'знак уважения': 1,
#           'уважения и': 2,
#           'и признательности': 1,
#           'признательности я': 1,
#           'я часто': 6,
#           'часто думаю': 6,
#           'думаю продолжала': 1,
#           'продолжала анна': 3,
#           'павловна после': 1,
#           'после минутного': 7,
#           'минутного молчания': 7,
#           'молчания подвигаясь': 1,
#           'подвигаясь к': 6,
#           'к князю': 54,
#           'князю и': 6,
#           'и ласково': 6,
#           'ласково улыбаясь': 1,
#           'улыбаясь ему': 3,
#           'ему как': 12,
#           'будто выказывая': 1,
#           'выказывая этим': 2,
#           'этим что': 4,
#           'что политические': 1,
#           'политические и': 1,
#           'и светские': 1,
#           'светские разговоры': 1,
#           'разговоры кончены': 1,
#           'кончены и': 2,
#           'и теперь': 64,
#           'теперь начинается': 1,
#           'начинается задушевный': 1,
#           'задушевный я': 1,
#           'думаю как': 1,
#           'как иногда': 2,
#           'иногда несправедливо': 1,
#           'несправедливо распределяется': 1,
#           'распределяется счастие': 1,
#           'счастие жизни': 3,
#           'жизни за': 1,
#           'за что': 66,
#           'что вам': 17,
#           'вам судьба': 1,
#           'судьба дала': 1,
#           'дала таких': 1,
#           'таких двух': 1,
#           'двух славных': 1,
#           'славных детей': 1,
#           'детей исключая': 1,
#           'исключая анатоля': 1,
#           'анатоля вашего': 1,
#           'вашего меньшого': 1,
#           'меньшого я': 1,
#           'я его': 41,
#           'его не': 100,
#           'не люблю': 21,
#           'люблю вставила': 1,
#           'вставила она': 1,
#           'она безапелляционно': 1,
#           'безапелляционно приподняв': 1,
#           'приподняв брови': 4,
#           'брови таких': 1,
#           'таких прелестных': 1,
#           'прелестных детей': 1,
#           'детей а': 2,
#           'а вы': 49,
#           'вы право': 2,
#           'право менее': 1,
#           'менее всех': 1,
#           'всех цените': 1,
#           'цените их': 1,
#           'их и': 41,
#           'и потому': 152,
#           'потому их': 1,
#           'их не': 17,
#           'не стоите': 1,
#           'стоите и': 2,
#           'и она': 102,
#           'она улыбнулась': 7,
#           'улыбнулась своею': 1,
#           'своею восторженною': 1,
#           'восторженною улыбкой': 1,
#           'улыбкой й': 1,
#           'й сказал': 43,
#           'князь перестаньте': 1,
#           'перестаньте шутить': 2,
#           'шутить я': 2,
#           'я хотела': 5,
#           'хотела серьезно': 1,
#           'серьезно поговорить': 1,
#           'поговорить с': 16,
#           'с вами': 69,
#           'вами знаете': 1,
#           'знаете я': 6,
#           'я недовольна': 1,
#           'недовольна вашим': 1,
#           'вашим меньшим': 1,
#           'меньшим сыном': 1,
#           'сыном между': 1,
#           'между нами': 10,
#           'нами будь': 1,
#           'будь сказано': 2,
#           'сказано лицо': 1,
#           'ее приняло': 3,
#           'приняло грустное': 1,
#           'грустное выражение': 2,
#           'выражение о': 1,
#           'о нем': 51,
#           'нем говорили': 1,
#           'говорили у': 1,
#           'у ее': 4,
#           'ее величества': 3,
#           'величества и': 2,
#           'и жалеют': 3,
#           'жалеют вас': 1,
#           'вас князь': 2,
#           'князь не': 13,
#           'не отвечал': 34,
#           'отвечал но': 2,
#           'но она': 68,
#           'она молча': 1,
#           'молча значительно': 1,
#           'значительно глядя': 2,
#           'глядя на': 180,
#           'на него': 286,
#           'него ждала': 1,
#           'ждала ответа': 1,
#           'ответа князь': 1,
#           'василий поморщился': 1,
#           'поморщился что': 1,
#           'вы хотите': 23,
#           'хотите чтоб': 3,
#           'чтоб я': 7,
#           'я делал': 3,
#           'делал сказал': 1,
#           'он наконец': 8,
#           'наконец вы': 1,
#           'я сделал': 9,
#           'сделал для': 5,
#           'для их': 2,
#           'их воспитания': 1,
#           'воспитания все': 1,
#           'все что': 84,
#           'что может': 13,
#           'может отец': 1,
#           'отец и': 11,
#           'и оба': 13,
#           'оба вышли': 1,
#           'вышли й': 1,
#           'й ипполит': 2,
#           'ипполит по': 1,
#           'по крайней': 19,
#           'крайней мере': 19,
#           'мере покойный': 1,
#           'покойный дурак': 1,
#           'дурак а': 2,
#           'а анатоль': 2,
#           'анатоль беспокойный': 1,
#           'беспокойный вот': 1,
#           'одно различие': 1,
#           'различие сказал': 1,
#           'он улыбаясь': 9,
#           'улыбаясь более': 1,
#           'более неестественно': 1,
#           'неестественно и': 4,
#           'и одушевленно': 1,
#           'одушевленно чем': 1,
#           'чем обыкновенно': 4,
#           'обыкновенно и': 2,
#           'при этом': 36,
#           'этом особенно': 1,
#           'особенно резко': 2,
#           'резко выказывая': 1,
#           'выказывая в': 1,
#           'в сложившихся': 1,
#           'сложившихся около': 1,
#           'около его': 3,
#           'его рта': 2,
#           'рта морщинах': 1,
#           ...})}
